# %% [markdown]
# <a href="https://colab.research.google.com/github/psbruno/Colab/blob/master/Bruno_Pires_A_aula_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
#--------------------------- K-Means Aggregation---------------------------

# %%
AggregationDs = pd.read_csv("http://cs.joensuu.fi/sipu/datasets/Aggregation.txt",sep="\t", header=None) #abrindo o dataset
AggregationDs.head()

# %%
sns.set_style("darkgrid")
sns.pairplot(AggregationDs, hue=2)#plotando o dataset

# %%
x=np.array(AggregationDs.drop(2,axis=1))
x

# %%
kmeans = KMeans(n_clusters=9)#treinando com 9 clusters
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=9, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
AggregationDs.head()

# %%
plt.scatter(x[:,1], x[:,0]) #plotando os grupos

# %%
#plt.xlim(0, 30) #range do eixo x
#plt.ylim(0, 40) #range do eixo y
plt.scatter(x[:,1], x[:,0])#grupos ao fundo
plt.scatter(kmeans.cluster_centers_[:,1],kmeans.cluster_centers_[:,0], c = 'red') #posição de cada centroide no gráfico
plt.show()

# %%
#--------------------------- Single Linkage Aggregation---------------------------

# %%
Z = linkage(AggregationDs, 'ward')
Z = linkage(AggregationDs, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

# %%
#--------------------------- K-Means D31---------------------------

# %%
D31DS = pd.read_csv("http://cs.joensuu.fi/sipu/datasets/D31.txt",sep="\t", header=None) 
sns.set_style("darkgrid")
sns.pairplot(D31DS, hue=2)

# %%
d=np.array(D31DS.drop(2,axis=1))
d

# %%
kmeans2 = KMeans(n_clusters=12)#12 clusters
kmeans2.fit(d)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=12, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(d[:,1], d[:,0]) #plotando os grupos

# %%
#plt.xlim(0, 50) #range do eixo x
#plt.ylim(0, 50) #range do eixo y
plt.scatter(d[:,1], d[:,0])#grupos ao fundo
plt.scatter(kmeans2.cluster_centers_[:,1],kmeans2.cluster_centers_[:,0], c = 'red') #posição de cada centroide no gráfico
plt.show()

# %%
#--------------------------- Single Linkage D31---------------------------

# %%
Z = linkage(D31DS, 'ward')
Z = linkage(D31DS, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

# %%
#--------------------------- K-Means Path-based1 ---------------------------

# %%
PB1 = pd.read_csv("http://cs.joensuu.fi/sipu/datasets/pathbased.txt",sep="\t", header=None) 
sns.set_style("darkgrid")
sns.pairplot(PB1, hue=2)

# %%
p=np.array(D31DS.drop(2,axis=1))

# %%
kmeans3 = KMeans(n_clusters=8)#8 Clusters
kmeans3.fit(p)

# %%
plt.scatter(p[:,1], p[:,0]) #plotando os grupos

# %%
plt.scatter(p[:,1], p[:,0])#grupos ao fundo
plt.scatter(kmeans3.cluster_centers_[:,1],kmeans3.cluster_centers_[:,0], c = 'red') #posição de cada centroide no gráfico
plt.show()

# %%
#--------------------------- Single Linkage Path-based1---------------------------

# %%
Z = linkage(PB1, 'ward')
Z = linkage(PB1, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

# %%
#--------------------------- K-Means Flame ---------------------------

# %%
flame = pd.read_csv("http://cs.joensuu.fi/sipu/datasets/flame.txt",sep="\t", header=None) 
sns.set_style("darkgrid")
sns.pairplot(flame, hue=2)

# %%
f=np.array(flame.drop(2,axis=1))

# %%
kmeans4 = KMeans(n_clusters=4)#4 Clusters
kmeans4.fit(f)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
plt.scatter(f[:,1], f[:,0]) #plotando os grupos

# %%
plt.scatter(f[:,1], f[:,0])#grupos ao fundo
plt.scatter(kmeans4.cluster_centers_[:,1],kmeans4.cluster_centers_[:,0], c = 'red') #posição de cada centroide no gráfico
plt.show()

# %%
#--------------------------- Single Linkage Flame---------------------------

# %%
Z = linkage(flame, 'ward')
Z = linkage(flame, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()
